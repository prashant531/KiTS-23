# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install monai

# %%
import torch
import torch.nn as nn

from monai.networks.blocks.convolutions import Convolution, ResidualUnit
from monai.networks.layers.factories import Act, Norm
from monai.networks.layers.simplelayers import SkipConnection
from monai.utils import alias, export

import warnings
from typing import Sequence, Tuple, Union

import torch
import torch.nn as nn

from monai.networks.blocks.convolutions import Convolution, ResidualUnit
from monai.networks.layers.factories import Act, Norm
from monai.networks.layers.simplelayers import SkipConnection
from monai.utils import alias, export

# %%
device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device('cpu')

# %%
class ChannelAttention(nn.Module):
    def __init__(self, submodule, in_planes, out_planes, ratio=16):
        super(ChannelAttention, self).__init__()
        self.submodule = submodule
        self.avg_pool = nn.AdaptiveAvgPool3d(1)
        self.max_pool = nn.AdaptiveMaxPool3d(1)
        self.in_planes = in_planes
        self.fc = nn.Sequential(nn.Conv3d(in_planes, in_planes // ratio, 1, bias=False),
                               nn.GELU(),
                               nn.Conv3d(in_planes // ratio, out_planes, 1, bias=False))

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # print("CAT X = ", x.shape, flush=True)
        y = self.submodule(x)
        # print("CAT Y = ", y.shape, flush=True)
        x_av = self.avg_pool(x)
        # print("CAT AVG MID = ", x.shape,  self.in_planes, flush=True)
        # print("FC = ", self.fc, flush=True)
        avg_out = self.fc(x_av)
        # print("CAT AVG = ", avg_out.shape, self.in_planes, flush=True)
        max_out = self.fc(self.max_pool(x))
        out = avg_out + max_out
        # print("CA output = ", y.shape, out.shape, avg_out.shape, self.in_planes, flush=True)
        # print("CHANNEL = ", out.shape)
        return y*self.sigmoid(out)

# %%
class SpatialAttention(nn.Module):
    def __init__(self, submodule, in_channels, kernel_size=7, out_channels=None, add_conv_1x1=False):
        super(SpatialAttention, self).__init__()
        self.submodule = submodule
        self.conv_flat = nn.Conv3d(in_channels, in_channels, 1, bias=False)
        self.conv1 = nn.Conv3d(2, 1, kernel_size, padding=kernel_size//2, bias=False)
        self.pool_layer = nn.MaxPool3d(2)
        self.upscale_layer = nn.Upsample(scale_factor=2, mode='nearest')
        self.gelu = nn.GELU()
        self.sigmoid = nn.Sigmoid()
        self.add_conv_1x1 = add_conv_1x1
        if add_conv_1x1:
            if out_channels is None:
                raise Exception("Out channels needed for conv 1x1")
            self.conv_1x1 = nn.Conv3d(in_channels, out_channels, 1, bias=False)
            self.act = torch.nn.PReLU()

    def forward(self, x):
        y = self.submodule(x)
        # x_2 = self.conv_flat(x)
        # print("X2 = ", x_2.shape)
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        # print("X = ", x.shape, y.shape, avg_out.shape, max_out.shape, flush=True)
        x = torch.cat([avg_out, max_out], dim=1)
        # print("X2 = ", x.shape, flush=True)
        x = self.conv1(x)
        if x.shape[-1] > y.shape[-1]:
            x = self.pool_layer(x)
        elif x.shape[-1] < y.shape[-1]:
            x = self.upscale_layer(x)
        # print("X3 = ", x.shape, y.shape, flush=True)
        # print("SPATIAL = ", x.shape)
        x = y*self.sigmoid(x)
        if self.add_conv_1x1:
            x = self.conv_1x1(x)
            x = self.act(x)
        return x

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_c=32, out_c=32, kernel_size=3, activation=nn.GELU):
        super(SpatialAttention, self).__init__()

        self.conv1 = nn.Conv3d(n_c, out_c, kernel_size, padding=kernel_size//2, bias=False)
        self.batchnorm = nn.BatchNorm3d(out_c)
        self.activation = activation()
        self.conv2 = nn.Conv3d(out_c, out_c, kernel_size, padding=kernel_size//2, bias=False)
        self.batchnorm2 = nn.BatchNorm3d(out_c)
        self.activation2 = activation()

    def forward(self, x):
        x = self.conv1(x)
        x = self.batchnorm(x)
        x = self.activation(x)
        x = self.conv2(x)
        x = self.batchnorm2(x)
        x = self.activation2(x)
        return x

# %%
__all__ = ["UNet", "Unet", "unet"]


@export("monai.networks.nets")
@alias("Unet")
class UNet(nn.Module):
    def __init__(
        self,
        dimensions: int,
        in_channels: int,
        out_channels: int,
        channels: Sequence[int],
        strides: Sequence[int],
        kernel_size: Union[Sequence[int], int] = 3,
        up_kernel_size: Union[Sequence[int], int] = 3,
        num_res_units: int = 0,
        act: Union[Tuple, str] = Act.PRELU,
        norm: Union[Tuple, str] = Norm.INSTANCE,
        dropout=0.0,
    ) -> None:
        super().__init__()

        if len(channels) < 2:
            raise ValueError(
                "the length of `channels` should be no less than 2.")
        delta = len(strides) - (len(channels) - 1)
        if delta < 0:
            raise ValueError(
                "the length of `strides` should equal to `len(channels) - 1`.")
        if delta > 0:
            warnings.warn(f"`len(strides) > len(channels) - 1`, the last {delta} values of strides will not be used.")
        if isinstance(kernel_size, Sequence):
            if len(kernel_size) != dimensions:
                raise ValueError(
                    "the length of `kernel_size` should equal to `dimensions`.")
        if isinstance(up_kernel_size, Sequence):
            if len(up_kernel_size) != dimensions:
                raise ValueError(
                    "the length of `up_kernel_size` should equal to `dimensions`.")

        self.dimensions = dimensions
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.channels = channels
        self.strides = strides
        self.kernel_size = kernel_size
        self.up_kernel_size = up_kernel_size
        self.num_res_units = num_res_units
        self.act = act
        self.norm = norm
        self.dropout = dropout

        def _create_block(
            inc: int,
            outc: int,
            channels: Sequence[int],
            strides: Sequence[int],
            is_top: bool) -> nn.Sequential:
            print("IN CREATE BLOCK : ", inc, outc, channels, strides, is_top)
            c = channels[0]
            s = strides[0]
            print(c, channels)
            subblock: nn.Module
            if len(channels)>2:
                subblock = _create_block(
                    c, c, channels[1:], strides[1:], False)                
                upc = c * 2
                if len(channels) > len(self.channels)-1:
                    add_spatial = True
                    add_channel = False
                else:
                    add_spatial = False
                    add_channel = False
            else:
                subblock = self._get_bottom_layer(c, channels[1])
                print("CREATED bottom LAYER : ", inc, outc, channels, strides, is_top)
                subblock = ChannelAttention(subblock, in_planes=c, out_planes=channels[1])
                # subblock = ChannelAttention(subblock, in_planes=channels[0])
                upc = c + channels[1]
                add_spatial = False
                add_channel = False

            down = self._get_down_layer(inc, c, s, is_top)
            print("CREATED DOWN LAYER : ", inc, c, s, is_top)
            if add_spatial:
                down = SpatialAttention(down, in_channels=inc)
            if add_channel:
                down = ChannelAttention(down, in_planes=inc, out_planes=c)

            
            if len(channels)==len(self.channels) and add_spatial:
                up = self._get_up_layer(upc, upc, s, is_top)
            else:
                up = self._get_up_layer(upc, outc, s, is_top)
            print("CREATED UP LAYER : ", upc, outc, s, is_top)
            # print(up, flush=True)
            if add_spatial:
                # print("CHANNELS = ", len(channels), channels[0], channels[1], flush=True)
                print("CH = ",channels, len(channels))
                add_conv_1x1 = len(channels)==len(self.channels)
                up = SpatialAttention(up, in_channels=upc, out_channels=outc, add_conv_1x1=add_conv_1x1)
            if add_channel:
                up = ChannelAttention(up, in_planes=upc, out_planes=outc)

            print("OUT OF CREATE BLOCK : ", inc, outc, channels, strides, is_top)
            return nn.Sequential(down, SkipConnection(subblock), up)

        self.model = _create_block(
            in_channels, out_channels, self.channels, self.strides, True)

    def _get_down_layer(self,
        in_channels: int,
        out_channels: int,
        strides: int,
        is_top: bool) -> nn.Module:
        # print("CREATING DOWN LAYER : ", in_channels, out_channels, strides, is_top)
        if self.num_res_units > 0:
            return ResidualUnit(
                self.dimensions,
                in_channels,
                out_channels,
                strides=strides,
                kernel_size=self.kernel_size,
                subunits=self.num_res_units,
                act=self.act,
                norm=self.norm,
                dropout=self.dropout,
            )
        return Convolution(
            self.dimensions,
            in_channels,
            out_channels,
            strides=strides,
            kernel_size=self.kernel_size,
            act=self.act,
            norm=self.norm,
            dropout=self.dropout,
        )

    def _get_bottom_layer(self, in_channels: int, out_channels: int) -> nn.Module:

        # print("CREATING bottom LAYER : ", in_channels, out_channels)
        return self._get_down_layer(in_channels, out_channels, 1, False)

    def _get_up_layer(self, in_channels: int, out_channels: int, strides: int, is_top: bool) -> nn.Module:

        # print("CREATING UP LAYER : ", in_channels, out_channels, strides, is_top)
        conv: Union[Convolution, nn.Sequential]

        conv = Convolution(
            self.dimensions,
            in_channels,
            out_channels,
            strides=strides,
            kernel_size=self.up_kernel_size,
            act=self.act,
            norm=self.norm,
            dropout=self.dropout,
            conv_only=is_top and self.num_res_units == 0,
            is_transposed=True,
        )

        if self.num_res_units > 0:
            ru = ResidualUnit(
                self.dimensions,
                out_channels,
                out_channels,
                strides=1,
                kernel_size=self.kernel_size,
                subunits=1,
                act=self.act,
                norm=self.norm,
                dropout=self.dropout,
                last_conv_only=is_top,
            )
            conv = nn.Sequential(conv, ru)

        return conv

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.model(x)
        return x


Unet = unet = UNet

# %%
# !pip install -U monai

# %%
import os
best_metric_model_file = "last_model.pth"

print(list(os.listdir('./')), flush=True)

import psutil
import argparse
import json
import logging
import sys
from monai.utils import first, set_determinism
from monai.transforms import (
    AsDiscrete,
    AsDiscreted,
    EnsureChannelFirstd,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    ScaleIntensityRanged,
    Spacingd,
    EnsureTyped,
    EnsureType,
    Invertd,
    RandAffined,
    RandShiftIntensityd,
    Rand3DElasticd,
    RandFlipd,
    RandGaussianNoised,
    CenterSpatialCropd,
    SpatialPadd,
    ToTensord,
    CastToTyped
)
# from monai.handlers.utils import 
from monai.networks.nets import UNet, UNETR, DynUNet
from monai.networks.layers import Norm
from monai.metrics import DiceMetric
from monai.losses import DiceLoss, DiceCELoss
from monai.inferers import sliding_window_inference
from monai.data import CacheDataset, DataLoader, Dataset, decollate_batch,SmartCacheDataset
from monai.config import print_config
from monai.apps import download_and_extract
import torch
import matplotlib.pyplot as plt
import tempfile
import shutil
import os
import glob
import numpy as np
# Out:
# ['.config', 'drive', 'sample_data']

# %%
root_data = '/content/drive/MyDrive/kits23/dataset'
root_dir = '/content/drive/MyDrive/model'

train_images=[]
train_labels=[]
for case in list(sorted(os.listdir(root_data))):
        train_images.append(root_data+"/"+case+"/imaging.nii.gz"),
        train_labels.append(root_data+"/"+case+"/segmentation.nii.gz")

data_dicts = [
    {"image": image_name, "label": label_name}
    for image_name, label_name in zip(train_images, train_labels)
]
# print(data_dicts[:6])

# %%
train_files, val_files = data_dicts[80:], data_dicts[:80]
# val_files.extend([data_dicts[151],data_dicts[156]])
print("VAL FILES = ", len(val_files), flush=True)
print("TRAIN FILES = ", len(train_files), flush=True)
print("MEMORY = ", str(round(psutil.virtual_memory().total / (1024.0 **3)))+" GB", flush=True)
# Out:
# VAL FILES =  80
# TRAIN FILES =  409
# MEMORY =  13 GB

# %%
train_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys=["image", "label"]),
        Spacingd(keys=["image", "label"], pixdim=(
            2, 1.62, 1.62), mode=("bilinear", "nearest")),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        ScaleIntensityRanged(
            keys=["image"], a_min=-80, a_max=305,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        CropForegroundd(keys=["image", "label"], source_key="image"),
        SpatialPadd(keys=["image", "label"], spatial_size=(160,160,64), mode="constant"),
        RandCropByPosNegLabeld(
            keys=["image", "label"],
            label_key="label",
            spatial_size=(160, 160, 64),
            pos=1,
            neg=1,
            num_samples=4,
            image_key="image",
            image_threshold=0,
        ),
        Rand3DElasticd(
            keys=["image", "label"],
            mode=("bilinear", "nearest"),
            prob=0.5,
            sigma_range=(5, 8),
            magnitude_range=(50, 150),
            spatial_size=(160, 160, 64),
            translate_range=(10, 10, 5),
            rotate_range=(np.pi/36,np.pi/36, np.pi),
            scale_range=(0.1, 0.1, 0.1),
            padding_mode="zeros",
        ),
        RandShiftIntensityd(
            keys=["image"],
            offsets=0.10,
            prob=0.25,
        ),
        RandGaussianNoised(keys=["image"], prob=0.25, mean=0.0, std=0.1),
        CastToTyped(keys=["label"], dtype=np.uint8),
        EnsureTyped(keys=["image", "label"]),
    ]
)
val_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        EnsureChannelFirstd(keys=["image", "label"]),
        Spacingd(keys=["image", "label"], pixdim=(
            2, 1.62, 1.62), mode=("bilinear", "nearest")),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        ScaleIntensityRanged(
            keys=["image"],a_min=-80, a_max=305,
            b_min=0.0, b_max=1.0, clip=True,
        ),
        CropForegroundd(keys=["image", "label"], source_key="image"),
        SpatialPadd(keys=["image", "label"], spatial_size=(160,160,64), mode="constant"),
        CastToTyped(keys=["label"], dtype=np.uint8),
        EnsureTyped(keys=["image", "label"]),
    ]
)

# %%
train_files = [d for d in train_files if d.get('image') != '/content/drive/MyDrive/kits23/dataset/case_00554/imaging.nii.gz']

# %%
print("CREATING TRAIN DS", flush=True)
print(train_files)
train_ds = SmartCacheDataset(
    data=train_files, transform=train_transforms,
    cache_rate=0.1, replace_rate=0.5)
print(len(train_ds))
# train_ds = Dataset(data=train_files, transform=train_transforms)
print("CREATED TRAIN DS", flush=True)
# use batch_size=2 to load images and use RandCropByPosNegLabeld
# to generate 2 x 4 images for network training
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=0)
print("CREATED TRAIN DATALOADER", flush=True)
# Out:
# CREATING TRAIN DS
# [{'image': '/content/drive/MyDrive/kits23/dataset/case_00080/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00080/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00081/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00081/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00082/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00082/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00083/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00083/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00084/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00084/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00085/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00085/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00086/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00086/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00087/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00087/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00088/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00088/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00089/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00089/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00090/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00090/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00091/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00091/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00092/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00092/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00093/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00093/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00094/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00094/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00095/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00095/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00096/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00096/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00097/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00097/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00098/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00098/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00099/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00099/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00100/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00100/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00101/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00101/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00102/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00102/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00103/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00103/segmentation.nii.gz'}, {'image': '/content/drive/MyDrive/kits23/dataset/case_00104/imaging.nii.gz', 'label': '/content/drive/MyDrive/kits23/dataset/case_00104/segmentation.nii.gz'}, {'image': '/content/driv ...
# Loading dataset: 100%|██████████| 40/40 [05:17<00:00,  7.93s/it]
# 40
# CREATED TRAIN DS
# CREATED TRAIN DATALOADER

# %%
val_ds = SmartCacheDataset(
    data=val_files, transform=val_transforms, cache_rate=0.1,replace_rate=0.5)
# val_ds = Dataset(data=val_files, transform=val_transforms)
print("CREATED VAL DS", flush=True)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=0)
print("CREATED VAL DATALOADER", flush=True)

device = torch.device("cuda:0") if torch.cuda.is_available() else torch.device('cpu')

# %%
print("CREATING MODEL", flush=True)
model = UNet(
    dimensions=3,
    in_channels=1,
    out_channels=4,
    channels=(64, 128, 256, 512, 512),
    strides=(2, 2, 2, 2), 
)
# model.load_state_dict(torch.load(best_metric_model_file,
#     map_location=torch.device(device)))

print("CREATED MODEL", flush=True)
loss_function = DiceCELoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.AdamW(model.parameters(), 1e-4)
dice_metric = DiceMetric(include_background=False, reduction="mean")

# %%
max_epochs = 25
val_interval = 1
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []
post_pred = Compose([EnsureType(), AsDiscrete(argmax=True, to_onehot=4)])
post_label = Compose([EnsureType(), AsDiscrete(to_onehot=4)])
model.to(device)

for epoch in range(max_epochs):
    print("-" * 10, flush=True)
    print(f"epoch {epoch + 1}/{max_epochs}", flush=True)
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = (
            batch_data["image"].to(device),
            batch_data["label"].to(device),
        )
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print(
            f"{step}/{len(train_ds) // train_loader.batch_size}, "
            f"train_loss: {loss.item():.4f}", flush=True)
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}", flush=True)

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                roi_size = (160,160, 64)
                sw_batch_size = 4
                val_outputs = sliding_window_inference(
                    val_inputs, roi_size, sw_batch_size, model)
                val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                # compute metric for current iteration
                dice_metric(y_pred=val_outputs, y=val_labels)

            # aggregate the final mean dice result
            metric = dice_metric.aggregate().item()
            # reset the status for next validation round
            dice_metric.reset()

            metric_values.append(metric)
            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(
                    root_dir, "best_metric_model_"+str(epoch)+"_"+str(f"{metric:.4f}")+".pth"))
                print("saved new best metric model", flush=True)
            print(
                f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
                f"\nbest mean dice: {best_metric:.4f} "
                f"at epoch: {best_metric_epoch}", flush=True
            )

torch.save(model.state_dict(), os.path.join(
                    root_dir, "last_model.pth"))
print(epoch_loss_values, flush=True)
print(metric_values, flush=True)
print(
f"train completed, best_metric: {best_metric:.4f} "
f"at epoch: {best_metric_epoch}", flush=True)
# Out:
# ----------
# epoch 1/25
# 1/20, train_loss: 2.4418
# 2/20, train_loss: 2.3788
# 3/20, train_loss: 2.3247
# 4/20, train_loss: 2.2836
# 5/20, train_loss: 2.2518
# 6/20, train_loss: 2.2114
# 7/20, train_loss: 2.1732
# 8/20, train_loss: 2.1501
# 9/20, train_loss: 2.1211
# 10/20, train_loss: 2.0984
# 11/20, train_loss: 2.0691
# 12/20, train_loss: 2.0587
# 13/20, train_loss: 2.0306
# 14/20, train_loss: 2.0101
# 15/20, train_loss: 1.9869
# 16/20, train_loss: 1.9626
# 17/20, train_loss: 1.9407
# 18/20, train_loss: 1.9282
# 19/20, train_loss: 1.9138
# 20/20, train_loss: 1.8963
# epoch 1 average loss: 2.1116
# saved new best metric model
# current epoch: 1 current mean dice: 0.0194
# best mean dice: 0.0194 at epoch: 1
# ----------
# epoch 2/25
# 1/20, train_loss: 1.8669
# 2/20, train_loss: 1.8751
# 3/20, train_loss: 1.8459
# 4/20, train_loss: 1.8327
# 5/20, train_loss: 1.8078
# 6/20, train_loss: 1.7977
# 7/20, train_loss: 1.8020
# 8/20, train_loss: 1.7661
# 9/20, train_loss: 1.7547
# 10/20, train_loss: 1.7543
# 11/20, train_loss: 1.7297
# 12/20, train_loss: 1.7208
# 13/20, train_loss: 1.7192
# 14/20, train_loss: 1.6942
# 15/20, train_loss: 1.6803
# 16/20, train_loss: 1.6859
# 17/20, train_loss: 1.6650
# 18/20, train_loss: 1.6537
# 19/20, train_loss: 1.6372
# 20/20, train_loss: 1.6282
# epoch 2 average loss: 1.7459
# current epoch: 2 current mean dice: 0.0160
# best mean dice: 0.0194 at epoch: 1
# ----------
# epoch 3/25
# 1/20, train_loss: 1.6154
# 2/20, train_loss: 1.5911
# 3/20, train_loss: 1.6028
# 4/20, train_loss: 1.5868
# 5/20, train_loss: 1.5859
# 6/20, train_loss: 1.5767
# 7/20, train_loss: 1.5614
# 8/20, train_loss: 1.5461
# 9/20, train_loss: 1.5375
# 10/20, train_loss: 1.5205
# 11/20, train_loss: 1.5202
# 12/20, train_loss: 1.5073
# 13/20, train_loss: 1.5076
# 14/20, train_loss: 1.4970
# 15/20, train_loss: 1.5089
# 16/20, train_loss: 1.5138
# 17/20, train_loss: 1.4645
# 18/20, train_loss: 1.4752
# 19/20, train_loss: 1.4668
# 20/20, train_loss: 1.4428
# epoch 3 average loss: 1.5314
# current epoch: 3 current mean dice: 0.0149
# best mean dice: 0.0194 at epoch: 1
# ----------
# epoch 4/25
# 1/20, train_loss: 1.4314
# 2/20, train_loss: 1.4259
# 3/20, train_loss: 1.4586
# 4/20, train_loss: 1.4355
# 5/20, train_loss: 1.3994
# 6/20, train_loss: 1.4139
# 7/20, train_loss: 1.4072
# 8/20, train_loss: 1.3914
# 9/20, train_loss: 1.3772
# 10/20, train_loss: 1.3841
# 11/20, train_loss: 1.3584
# 12/20, train_loss: 1.3595
# 13/20, train_loss: 1.3626
# 14/20, train_loss: 1.3402
# 15/20, train_loss: 1.3706
# 16/20, train_loss: 1.3318
# 17/20, train_loss: 1.3381
# 18/20, train_loss: 1.3229
# 19/20, train_loss: 1.3481
# 20/20, train_loss: 1.3001
# epoch 4 average loss: 1.3778
# current epoch: 4 current mean dice: 0.0142
# best mean dice: 0.0194 at epoch: 1
# ----------
# epoch 5/25
# 1/20, train_loss: 1.3091
# 2/20, train_loss: 1.3095
# 3/20, train_loss: 1.2923
# 4/20, train_loss: 1.3502
# 5/20, train_loss: 1.2888
# 6/20, train_loss: 1.2998
# 7/20, train_loss: 1.2905
# 8/20, train_loss: 1.2859
# 9/20, train_loss: 1.2813
# 10/20, train_loss: 1.2741
# 11/20, train_loss: 1.2635
# 12/20, train_loss: 1.3048
# 13/20, train_loss: 1.2548
# 14/20, train_loss: 1.2384
# 15/20, train_loss: 1.2429
# 16/20, train_loss: 1.2287
# 17/20, train_loss: 1.2533
# 18/20, train_loss: 1.2216
# 19/20, train_loss: 1.2227
# 20/20, train_loss: 1.2156
# epoch 5 average loss: 1.2714
# saved new best metric model
# current epoch: 5 current mean dice: 0.0375
# best mean dice: 0.0375 at epoch: 5
# ----------
# epoch 6/25
# 1/20, train_loss: 1.2324
# 2/20, train_loss: 1.2069
# 3/20, train_loss: 1.2098
# 4/20, train_loss: 1.2212
# 5/20, train_loss: 1.1859
# 6/20, train_loss: 1.2540
# 7/20, train_loss: 1.1798
# 8/20, train_loss: 1.1867
# 9/20, train_loss: 1.1811
# 10/20, train_loss: 1.2180
# 11/20, train_loss: 1.1858
# 12/20, train_loss: 1.1696
# 13/20, train_loss: 1.1570
# 14/20, train_loss: 1.1586
# 15/20, train_loss: 1.1665
# 16/20, train_loss: 1.1404
# 17/20, train_loss: 1.2194
# 18/20, train_loss: 1.1805
# 19/20, train_loss: 1.1449
# 20/20, train_loss: 1.1423
# epoch 6 average loss: 1.1870
# saved new best metric model
# current epoch: 6 current mean dice: 0.0667
# best mean dice: 0.0667 at epoch: 6
# ----------
# epoch 7/25
# 1/20, train_loss: 1.1463
# 2/20, train_loss: 1.1664
# 3/20, train_loss: 1.1495
# 4/20, train_loss: 1.1226
# 5/20, train_loss: 1.1812
# 6/20, train_loss: 1.1365
# 7/20, train_loss: 1.1118
# 8/20, train_loss: 1.1102
# 9/20, train_loss: 1.1017
# 10/20, train_loss: 1.0899
# 11/20, train_loss: 1.1280
# 12/20, train_loss: 1.0906
# 13/20, train_loss: 1.1205
# 14/20, train_loss: 1.0972
# 15/20, train_loss: 1.0744
# 16/20, train_loss: 1.0760
# 17/20, train_loss: 1.2041
# 18/20, train_loss: 1.0771
# 19/20, train_loss: 1.0517
# 20/20, train_loss: 1.0858
# epoch 7 average loss: 1.1161
# saved new best metric model
# current epoch: 7 current mean dice: 0.1483
# best mean dice: 0.1483 at epoch: 7
# ----------
# epoch 8/25
# 1/20, train_loss: 1.1397
# 2/20, train_loss: 1.0585
# 3/20, train_loss: 1.0674
# 4/20, train_loss: 1.0424
# 5/20, train_loss: 1.0406
# 6/20, train_loss: 1.0865
# 7/20, train_loss: 1.0577
# 8/20, train_loss: 1.0854
# 9/20, train_loss: 1.0617
# 10/20, train_loss: 1.0340
# 11/20, train_loss: 1.0557
# 12/20, train_loss: 1.0363
# 13/20, train_loss: 1.0405
# 14/20, train_loss: 1.0680
# 15/20, train_loss: 1.0656
# 16/20, train_loss: 1.0730
# 17/20, train_loss: 1.0253
# 18/20, train_loss: 1.0383
# 19/20, train_loss: 1.0216
# 20/20, train_loss: 1.0040
# epoch 8 average loss: 1.0551
# saved new best metric model
# current epoch: 8 current mean dice: 0.1722
# best mean dice: 0.1722 at epoch: 8
# ----------
# epoch 9/25
# 1/20, train_loss: 1.0353
# 2/20, train_loss: 1.0693
# 3/20, train_loss: 0.9930
# 4/20, train_loss: 1.0057
# 5/20, train_loss: 1.1148
# 6/20, train_loss: 1.0260
# 7/20, train_loss: 0.9991
# 8/20, train_loss: 1.0146
# 9/20, train_loss: 1.0168
# 10/20, train_loss: 1.0066
# 11/20, train_loss: 1.0243
# 12/20, train_loss: 1.0031
# 13/20, train_loss: 0.9741
# 14/20, train_loss: 1.0386
# 15/20, train_loss: 0.9564
# 16/20, train_loss: 0.9483
# 17/20, train_loss: 0.9985
# 18/20, train_loss: 1.0046
# 19/20, train_loss: 0.9688
# 20/20, train_loss: 0.9603
# epoch 9 average loss: 1.0079
# saved new best metric model
# current epoch: 9 current mean dice: 0.2027
# best mean dice: 0.2027 at epoch: 9
# ----------
# epoch 10/25
# 1/20, train_loss: 0.9987
# 2/20, train_loss: 0.9727
# 3/20, train_loss: 0.9509
# 4/20, train_loss: 0.9942
# 5/20, train_loss: 0.9531
# 6/20, train_loss: 1.0706
# 7/20, train_loss: 0.9301
# 8/20, train_loss: 0.9480
# 9/20, train_loss: 0.9359
# 10/20, train_loss: 1.0073
# 11/20, train_loss: 0.9429
# 12/20, train_loss: 0.9248
# 13/20, train_loss: 0.9833
# 14/20, train_loss: 0.9768
# 15/20, train_loss: 0.9535
# 16/20, train_loss: 0.9348
# 17/20, train_loss: 0.9137
# 18/20, train_loss: 0.9606
# 19/20, train_loss: 1.0571
# 20/20, train_loss: 0.9646
# epoch 10 average loss: 0.9687
# current epoch: 10 current mean dice: 0.1985
# best mean dice: 0.2027 at epoch: 9
# ----------
# epoch 11/25
# 1/20, train_loss: 0.8939
# 2/20, train_loss: 0.9294
# 3/20, train_loss: 0.9368
# 4/20, train_loss: 1.0316
# 5/20, train_loss: 0.9520
# 6/20, train_loss: 0.9592
# 7/20, train_loss: 0.9687
# 8/20, train_loss: 1.0694
# 9/20, train_loss: 0.9401
# 10/20, train_loss: 0.9130
# 11/20, train_loss: 0.8957
# 12/20, train_loss: 0.9107
# 13/20, train_loss: 0.9124
# 14/20, train_loss: 0.9153
# 15/20, train_loss: 1.0036
# 16/20, train_loss: 0.9282
# 17/20, train_loss: 0.8900
# 18/20, train_loss: 0.9005
# 19/20, train_loss: 0.9261
# 20/20, train_loss: 0.9387
# epoch 11 average loss: 0.9408
# saved new best metric model
# current epoch: 11 current mean dice: 0.2290
# best mean dice: 0.2290 at epoch: 11
# ----------
# epoch 12/25
# 1/20, train_loss: 0.8991
# 2/20, train_loss: 0.9396
# 3/20, train_loss: 0.8949
# 4/20, train_loss: 0.8933
# 5/20, train_loss: 0.9189
# 6/20, train_loss: 0.9720
# 7/20, train_loss: 0.8738
# 8/20, train_loss: 0.9488
# 9/20, train_loss: 0.8757
# 10/20, train_loss: 0.9046
# 11/20, train_loss: 0.8940
# 12/20, train_loss: 0.8586
# 13/20, train_loss: 0.8849
# 14/20, train_loss: 0.8772
# 15/20, train_loss: 0.8835
# 16/20, train_loss: 1.0423
# 17/20, train_loss: 0.8879
# 18/20, train_loss: 0.8353
# 19/20, train_loss: 0.8876
# 20/20, train_loss: 0.8903
# epoch 12 average loss: 0.9031
# saved new best metric model
# current epoch: 12 current mean dice: 0.2525
# best mean dice: 0.2525 at epoch: 12
# ----------
# epoch 13/25
# 1/20, train_loss: 0.8453
# 2/20, train_loss: 0.8744
# 3/20, train_loss: 0.9292
# 4/20, train_loss: 0.8656
# 5/20, train_loss: 0.8681
# 6/20, train_loss: 0.9039
# 7/20, train_loss: 0.8676
# 8/20, train_loss: 1.0413
# 9/20, train_loss: 0.9038
# 10/20, train_loss: 0.8744
# 11/20, train_loss: 0.9352
# 12/20, train_loss: 0.8614
# 13/20, train_loss: 0.8976
# 14/20, train_loss: 0.8296
# 15/20, train_loss: 0.8677
# 16/20, train_loss: 0.8505
# 17/20, train_loss: 0.8647
# 18/20, train_loss: 0.8411
# 19/20, train_loss: 0.9381
# 20/20, train_loss: 0.8581
# epoch 13 average loss: 0.8859
# current epoch: 13 current mean dice: 0.2307
# best mean dice: 0.2525 at epoch: 12
# ----------
# epoch 14/25
# 1/20, train_loss: 0.8594
# 2/20, train_loss: 0.8035
# 3/20, train_loss: 0.8118
# 4/20, train_loss: 0.8348
# 5/20, train_loss: 0.8638
# 6/20, train_loss: 0.8467
# 7/20, train_loss: 0.8579
# 8/20, train_loss: 0.8492
# 9/20, train_loss: 0.7892
# 10/20, train_loss: 0.8784
# 11/20, train_loss: 0.9851
# 12/20, train_loss: 0.8494
# 13/20, train_loss: 0.8608
# 14/20, train_loss: 0.8682
# 15/20, train_loss: 0.8545
# 16/20, train_loss: 0.8582
# 17/20, train_loss: 0.8620
# 18/20, train_loss: 0.8547
# 19/20, train_loss: 0.9284
# 20/20, train_loss: 0.8887
# epoch 14 average loss: 0.8602
# current epoch: 14 current mean dice: 0.2234
# best mean dice: 0.2525 at epoch: 12
# ----------
# epoch 15/25
# 1/20, train_loss: 0.8593
# 2/20, train_loss: 0.8220
# 3/20, train_loss: 0.8017
# 4/20, train_loss: 0.8797
# 5/20, train_loss: 0.9813
# 6/20, train_loss: 0.8444
# 7/20, train_loss: 0.9226
# 8/20, train_loss: 0.8463
# 9/20, train_loss: 0.8581
# 10/20, train_loss: 0.8555
# 11/20, train_loss: 0.8364
# 12/20, train_loss: 0.7989
# 13/20, train_loss: 0.8088
# 14/20, train_loss: 0.8455
# 15/20, train_loss: 0.7856
# 16/20, train_loss: 0.7827
# 17/20, train_loss: 0.8212
# 18/20, train_loss: 0.8642
# 19/20, train_loss: 0.8187
# 20/20, train_loss: 0.8530
# epoch 15 average loss: 0.8443
# saved new best metric model
# current epoch: 15 current mean dice: 0.2550
# best mean dice: 0.2550 at epoch: 15
# ----------
# epoch 16/25
# 1/20, train_loss: 0.8465
# 2/20, train_loss: 0.7569
# 3/20, train_loss: 0.8256
# 4/20, train_loss: 0.8469
# 5/20, train_loss: 0.8060
# 6/20, train_loss: 0.8431
# 7/20, train_loss: 0.7779
# 8/20, train_loss: 0.8047
# 9/20, train_loss: 0.8117
# 10/20, train_loss: 0.8341
# 11/20, train_loss: 0.7482
# 12/20, train_loss: 0.8161
# 13/20, train_loss: 0.9128
# 14/20, train_loss: 0.8470
# 15/20, train_loss: 0.7960
# 16/20, train_loss: 0.8019
# 17/20, train_loss: 0.7581
# 18/20, train_loss: 0.8566
# 19/20, train_loss: 0.8433
# 20/20, train_loss: 0.7572
# epoch 16 average loss: 0.8145
# current epoch: 16 current mean dice: 0.2527
# best mean dice: 0.2550 at epoch: 15
# ----------
# epoch 17/25
# 1/20, train_loss: 0.8885
# 2/20, train_loss: 0.8251
# 3/20, train_loss: 0.7685
# 4/20, train_loss: 0.7900
# 5/20, train_loss: 0.7970
# 6/20, train_loss: 0.7862
# 7/20, train_loss: 0.7572
# 8/20, train_loss: 0.7749
# 9/20, train_loss: 0.8255
# 10/20, train_loss: 0.7455
# 11/20, train_loss: 0.7963
# 12/20, train_loss: 0.9505
# 13/20, train_loss: 0.7629
# 14/20, train_loss: 0.7824
# 15/20, train_loss: 0.8231
# 16/20, train_loss: 0.8291
# 17/20, train_loss: 0.7448
# 18/20, train_loss: 0.8268
# 19/20, train_loss: 0.7656
# 20/20, train_loss: 0.8843
# epoch 17 average loss: 0.8062
# saved new best metric model
# current epoch: 17 current mean dice: 0.2817
# best mean dice: 0.2817 at epoch: 17
# ----------
# epoch 18/25
# 1/20, train_loss: 0.8093
# 2/20, train_loss: 0.7899
# 3/20, train_loss: 0.7621
# 4/20, train_loss: 0.8084
# 5/20, train_loss: 0.7667
# 6/20, train_loss: 0.8505
# 7/20, train_loss: 0.7498
# 8/20, train_loss: 0.7840
# 9/20, train_loss: 0.7711
# 10/20, train_loss: 0.7691
# 11/20, train_loss: 0.7961
# 12/20, train_loss: 0.7731
# 13/20, train_loss: 0.8512
# 14/20, train_loss: 0.7729
# 15/20, train_loss: 0.7983
# 16/20, train_loss: 0.7693
# 17/20, train_loss: 1.0016
# 18/20, train_loss: 0.7809
# 19/20, train_loss: 0.7149
# 20/20, train_loss: 0.8247
# epoch 18 average loss: 0.7972
# current epoch: 18 current mean dice: 0.2261
# best mean dice: 0.2817 at epoch: 17
# ----------
# epoch 19/25
# 1/20, train_loss: 0.8741
# 2/20, train_loss: 0.7573
# 3/20, train_loss: 0.7965
# 4/20, train_loss: 0.8052
# 5/20, train_loss: 0.8109
# 6/20, train_loss: 0.7903
# 7/20, train_loss: 0.8055
# 8/20, train_loss: 0.7733
# 9/20, train_loss: 0.7735
# 10/20, train_loss: 0.7738
# 11/20, train_loss: 0.7668
# 12/20, train_loss: 0.7523
# 13/20, train_loss: 0.8845
# 14/20, train_loss: 0.7454
# 15/20, train_loss: 0.7761
# 16/20, train_loss: 0.7290
# 17/20, train_loss: 0.7772
# 18/20, train_loss: 0.7555
# 19/20, train_loss: 0.7918
# 20/20, train_loss: 0.7870
# epoch 19 average loss: 0.7863
# current epoch: 19 current mean dice: 0.2542
# best mean dice: 0.2817 at epoch: 17
# ----------
# epoch 20/25
# 1/20, train_loss: 0.7720
# 2/20, train_loss: 0.7589
# 3/20, train_loss: 0.6850
# 4/20, train_loss: 0.7939
# 5/20, train_loss: 0.7653
# 6/20, train_loss: 0.7508
# 7/20, train_loss: 0.8279
# 8/20, train_loss: 0.7513
# 9/20, train_loss: 0.7103
# 10/20, train_loss: 0.7657
# 11/20, train_loss: 0.7247
# 12/20, train_loss: 0.7894
# 13/20, train_loss: 0.7291
# 14/20, train_loss: 0.7858
# 15/20, train_loss: 0.8090
# 16/20, train_loss: 0.7403
# 17/20, train_loss: 0.7477
# 18/20, train_loss: 0.7611
# 19/20, train_loss: 0.8377
# 20/20, train_loss: 0.7621
# epoch 20 average loss: 0.7634
# saved new best metric model
# current epoch: 20 current mean dice: 0.2829
# best mean dice: 0.2829 at epoch: 20
# ----------
# epoch 21/25
# 1/20, train_loss: 0.7478
# 2/20, train_loss: 0.7679
# 3/20, train_loss: 0.7915
# 4/20, train_loss: 0.8110
# 5/20, train_loss: 0.6855
# 6/20, train_loss: 0.7190
# 7/20, train_loss: 0.7564
# 8/20, train_loss: 0.7319
# 9/20, train_loss: 0.7033
# 10/20, train_loss: 0.7274
# 11/20, train_loss: 0.8277
# 12/20, train_loss: 0.7490
# 13/20, train_loss: 0.7294
